# %%
import matplotlib.pyplot as plt


# ROUND 1
round1_acc = [0.3587111111111111, 0.4709333333333333, 0.5256, 0.5163555555555556, 0.562, 0.5864, 0.6096, 0.6342666666666666, 0.6543555555555556, 0.6703111111111111, 0.6836888888888889, 0.7032888888888889, 0.7141777777777778, 0.7312888888888889, 0.7419555555555556, 0.7464888888888889]

# ROUND 2
round2_acc = [0.6063111111111111, 0.6711111111111111, 0.7043555555555555, 0.7283111111111111, 0.7476888888888888, 0.7712, 0.7888444444444445, 0.8060444444444445, 0.8235111111111111, 0.84, 0.8526222222222222, 0.8600888888888889, 0.8769777777777777, 0.888, 0.8894222222222222]

# ROUND 3
round3_acc = [0.6892, 0.7662666666666667, 0.8048888888888889, 0.8314222222222222, 0.8594666666666667, 0.8713777777777778, 0.8841777777777777, 0.9000444444444444, 0.9063555555555556, 0.9170666666666667, 0.9213777777777777, 0.9216, 0.9336444444444445, 0.9388888888888889, 0.9367555555555556]

fig, ax = plt.subplots(figsize=(12, 6))
x = range(1, 16)

ax.plot(x, round1_acc[:15], label='Round 1')
ax.plot(x, round2_acc[:15], label='Round 2')
ax.plot(x, round3_acc[:15], label='Round 3')


ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy per Epoch')
ax.legend()

plt.savefig('accuracy.png')
plt.show()

# %%
import matplotlib.pyplot as plt

round1_loss = [0.05795181170105934, 0.04851354658603668, 0.04426521435379982, 0.04424278065562248, 0.04103692248463631, 0.038511503487825394, 0.03627004846930504, 0.03448741137981415, 0.03273320198059082, 0.031177224591374397, 0.029854251071810722, 0.028206782415509224, 0.026868997141718864, 0.025380752980709076, 0.02419351041316986, 0.023264583200216293]
round2_loss = [0.037225089967250824, 0.03112811967730522, 0.028083018958568573, 0.025522449985146523, 0.023574229329824448, 0.021542100235819817, 0.019679440185427666, 0.018196363002061844, 0.01653079129755497, 0.01512083224952221, 0.014039438217878342, 0.012811940163373947, 0.011542941443622112, 0.010534962639212608, 0.010169574990868568]
round3_loss = [0.029641639441251755, 0.021840346977114677, 0.018353784456849098, 0.01557877752929926, 0.01328355260193348, 0.011954973451793194, 0.010899623855948448, 0.009474577382206917, 0.00875449925661087, 0.007958892732858658, 0.00734433950856328, 0.007380334660410881, 0.006256207823753357, 0.005839843302965164, 0.00605950178578496]
fig, ax = plt.subplots(figsize=(12, 6))
x = range(1, 16)

ax.plot(x, round1_loss[:15], label='Round 1')
ax.plot(x, round2_loss[:15], label='Round 2')
ax.plot(x, round3_loss[:15], label='Round 3')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss per Epoch')
ax.legend()

plt.savefig('loss.png')
plt.show()
