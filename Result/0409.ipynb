# %%
import matplotlib.pyplot as plt

round1_acc = [0.34993684210526316, 0.346821052631579, 0.47372631578947366, 0.46442105263157896, 0.5165052631578947]
round2_acc = [0.34433684210526316, 0.4647578947368421, 0.5170526315789473, 0.5558736842105263, 0.5848842105263158]
round3_acc = [0.3535578947368421, 0.4688842105263158, 0.5213473684210527, 0.5625263157894737, 0.5757052631578947]

fig, ax = plt.subplots(figsize=(12, 6))
x = range(1, 6)

ax.plot(x, round1_acc, label='Round 1')
ax.plot(x, round2_acc, label='Round 2')
ax.plot(x, round3_acc, label='Round 3')

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy per Epoch')
ax.legend()

plt.savefig('accuracy.png')
plt.show()

# %%
import matplotlib.pyplot as plt

round1_loss = [0.04366038367152214, 0.04440964385867119, 0.03614255413413048, 0.036764346063137054, 0.03329597786068916]
round2_loss = [0.044717926532030106, 0.03686114400625229, 0.033519357442855835, 0.031095029786229134, 0.02912336029112339]
round3_loss = [0.0441487617790699, 0.03652910515666008, 0.03304485231637955, 0.030588839203119278, 0.029734531417489052]

fig, ax = plt.subplots(figsize=(12, 6))
x = range(1, 6)

ax.plot(x, round1_loss, label='Round 1')
ax.plot(x, round2_loss, label='Round 2')
ax.plot(x, round3_loss, label='Round 3')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss per Epoch')
ax.legend()

plt.savefig('loss.png')
plt.show()

# %%
import matplotlib.pyplot as plt

round1_acc = [0.3549894736842105, 0.3542315789473684, 0.4727157894736842, 0.4688842105263158, 0.5173052631578947, 0.5172210526315789, 0.5550736842105263, 0.5526736842105263, 0.5792842105263157, 0.5762526315789473, 0.604421052631579, 0.5978105263157895, 0.6237052631578948, 0.6176, 0.6420210526315789, 0.6340210526315789, 0.6572210526315789, 0.6459789473684211, 0.6750736842105263, 0.6611368421052631]
round2_acc = [0.35242105263157897, 0.45793684210526314, 0.5070315789473684, 0.539578947368421, 0.5661894736842106, 0.5912, 0.6104842105263157, 0.6128, 0.6254736842105263, 0.6423578947368421, 0.6554526315789474, 0.658021052631579]
round3_acc = [0.3542315789473684, 0.4610947368421053, 0.5102315789473684, 0.5449263157894737, 0.5741894736842105, 0.5984421052631579, 0.6229473684210526, 0.6354947368421052, 0.651578947368421, 0.6710736842105263]
round4_acc = [0.35789473684210527, 0.4655578947368421, 0.5094315789473685, 0.5485894736842105, 0.5768421052631579, 0.5996631578947368, 0.6212631578947369, 0.6347368421052632, 0.6526315789473685, 0.6651789473684211]

fig, ax = plt.subplots(figsize=(12, 6))
x = range(1, 21)

ax.plot(x, round1_acc, label='Round 1')
ax.plot(x[0:12], round2_acc, label='Round 2')
ax.plot(x[0:10], round3_acc, label='Round 3')
ax.plot(x[0:10], round4_acc, label='Round 4')

ax.set_xlabel('Epoch')
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy per Epoch')
ax.legend()

plt.savefig('accuracy.png')
plt.show()

# %%
round1_loss = [0.04326454922556877, 0.04329577460885048, 0.03637862205505371, 0.036426614969968796, 0.0332813635468483, 0.03356106951832771, 0.0310431569814682, 0.031373780220746994, 0.02926727570593357, 0.029656892642378807, 0.02784539759159088, 0.028254883363842964, 0.026508409529924393, 0.02701958455145359, 0.02525295875966549, 0.026008328422904015, 0.024159176275134087, 0.02485516294836998, 0.023019159212708473, 0.023815589025616646]
round2_loss = [0.04358283802866936, 0.037013549357652664, 0.033999036997556686, 0.031918589025735855, 0.030199658125638962, 0.028707310557365417, 0.027337362989783287, 0.027221227064728737, 0.026302414014935493, 0.02501140721142292, 0.024078790098428726, 0.023883329704403877]
round3_loss = [0.043523721396923065, 0.03666582703590393, 0.03377749025821686, 0.03155073896050453, 0.029764769598841667, 0.028018180280923843, 0.02659449353814125, 0.02560044638812542, 0.024495631456375122, 0.02336299791932106]
round4_loss = [0.04341290518641472, 0.03667796403169632, 0.0337405651807785, 0.031474750488996506, 0.029668739065527916, 0.02810637652873993, 0.026816146448254585, 0.025707555934786797, 0.024458082392811775, 0.023628799244761467]

fig, ax = plt.subplots(figsize=(12, 6))
x = range(1, 21)

ax.plot(x, round1_loss, label='Round 1')
ax.plot(x[0:12], round2_loss, label='Round 2')
ax.plot(x[0:10], round3_loss, label='Round 3')
ax.plot(x[0:10], round4_loss, label='Round 4')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.set_title('Loss per Epoch')
ax.legend()

plt.savefig('loss.png')
plt.show()
